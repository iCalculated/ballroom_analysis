# %% [raw]
# ---
# description: Scoring rules for dancers and events
# output-file: scoring.html
# title: scoring
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(score)
# Out:
# ---
#
# [source](https://github.com/iCalculated/ballroom_analysis/blob/main/ballroom_analysis/scoring.py#L11){target="_blank" style="float:right; font-size:smaller"}
#
# ### score
#
# >      score (data)

# %%
#| echo: false
#| output: asis
show_doc(score_result)
# Out:
# ---
#
# ### score_result
#
# >      score_result (result:ballroom_analysis.scraping.Result)
